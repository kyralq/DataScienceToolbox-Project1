# %%
# !pip install matplotlib numpy pandas scikit_learn
# Out:
# Requirement already satisfied: matplotlib in /Users/Kyra/anaconda3/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: numpy in /Users/Kyra/anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: pandas in /Users/Kyra/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: scikit_learn in /Users/Kyra/anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.5.0 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from scikit_learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from scikit_learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from scikit_learn) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Users/Kyra/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')
df.shape
# Out:
# (5110, 12)

# %% [markdown]
# Now we want to seperate our the features (inputs / explanatory variables) from the labels (output ie stroke or not stroke).

# %%
features_pd= df.iloc[:,:df.shape[1]-1]
labels_pd= df.iloc[:,df.shape[1]-1:]
labels= labels_pd.values.ravel()

# %% [markdown]
# Now we want to split the data into training and testing. Here we use stratify to make sure we have an even split of stroke/ not stroke in our training and test data sets.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features_pd, 
    labels, 
    train_size=0.8, 
    test_size=0.2,
    random_state=1,
    stratify=labels)
print ("X_train, y_train:", X_train.shape, y_train.shape)
print ("X_test, y_test:", X_test.shape, y_test.shape)

print("Proportion stroke in train: ", np.sum(y_train) / len(y_train))
print("Proportion stroke in test: ", np.sum(y_test) / len(y_test))
# Out:
# X_train, y_train: (4088, 11) (4088,)
# X_test, y_test: (1022, 11) (1022,)
# Proportion stroke in train:  0.04867906066536203
# Proportion stroke in test:  0.04892367906066536

# %% [markdown]
# Let's put them back together so we can convert into a csv for the whole group to use the same data split in R/Python. Just with a quick check that the X and y have joined up correctly.

# %%
training_dataset = pd.concat(
    [X_train, pd.DataFrame(y_train, index=X_train.index, columns=['stroke'])],
    axis=1
)

testing_dataset = pd.concat(
    [X_test, pd.DataFrame(y_test, index=X_test.index, columns=['stroke'])],
    axis=1
)

# %%
testing_dataset = testing_dataset.sort_index()
training_dataset = training_dataset.sort_index()

print("Combined Training Data Shape:", training_dataset.shape)
print("Combined Testing Data Shape:", testing_dataset.shape)

training_dataset.head(20)
# Out:
# Combined Training Data Shape: (4088, 12)
# Combined Testing Data Shape: (1022, 12)
#        id  gender   age  hypertension  heart_disease ever_married  \
# 0    9046    Male  67.0             0              1          Yes
# 1   51676  Female  61.0             0              0          Yes
# 2   31112    Male  80.0             0              1          Yes
# 3   60182  Female  49.0             0              0          Yes
# 4    1665  Female  79.0             1              0          Yes
# 6   53882    Male  74.0             1              1          Yes
# 7   10434  Female  69.0             0              0           No
# 8   27419  Female  59.0             0              0          Yes
# 9   60491  Female  78.0             0              0          Yes
# 10  12109  Female  81.0             1              0          Yes
# 11  12095  Female  61.0             0              1          Yes
# 13   8213    Male  78.0             0              1          Yes
# 14   5317  Female  79.0             0              1          Yes
# 15  58202  Female  50.0             1              0          Yes
# 16  56112    Male  64.0             0              1          Yes
# 17  34120    Male  75.0             1              0          Yes
# 18  27458  Female  60.0             0              0           No
# 19  25226    Male  57.0             0              1           No
# 20  70630  Female  71.0             0              0          Yes
# 21  13861  Female  52.0             1              0          Yes
#
#         work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0         Private          Urban             228.69  36.6  formerly smoked
# 1   Self-employed          Rural             202.21   NaN     never smoked
# 2         Private          Rural             105.92  32.5     never smoked
# 3         Private          Urban             171.23  34.4           smokes
# 4   Self-employed          Rural             174.12  24.0     never smoked
# 6         Private          Rural              70.09  27.4     never smoked
# 7         Private          Urban              94.39  22.8     never smoked
# 8         Private          Rural              76.15   NaN          Unknown
# 9         Private          Urban              58.57  24.2          Unknown
# 10        Private          Rural              80.43  29.7     never smoked
# 11       Govt_job          Rural             120.46  36.8           smokes
# 13        Private          Urban             219.84   NaN          Unknown
# 14        Private          Urban             214.09  28.2     never smoked
# 15  Self-employed          Rural             167.41  30.9     never smoked
# 16        Private          Urban             191.61  37.5           smokes
# 17        Private          Urban             221.29  25.8           smokes
# 18        Private          Urban              89.22  37.8     never smoked
# 19       Govt_job          Urban             217.08   NaN          Unknown
# 20       Govt_job          Rural             193.94  22.4           smokes
# 21  Self-employed          Urban             233.29  48.9     never smoked
#
#     stroke
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# 6        1
# 7        1
# 8        1
# 9        1
# 10       1
# 11       1
# 13       1
# 14       1
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       1
# 21       1

# %%
training_dataset.to_csv('stroke_training_dataset.csv', index=False)
testing_dataset.to_csv('stroke_testing_dataset.csv', index=False)
# Out:
# "\ntraining_dataset.to_csv('stroke_training_dataset.csv', index=False)\ntesting_dataset.to_csv('stroke_testing_dataset.csv', index=False)\n"
